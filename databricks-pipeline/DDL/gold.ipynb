# %% [markdown]
# ## dim_users

# %%
# %sql
CREATE TABLE realstate.gold.dim_users (
    id BIGINT GENERATED ALWAYS AS IDENTITY,
    user_id INT,
    user_name STRING,
    advertiser_type STRING,
    is_verified STRING,
    is_active INT
)using delta 
LOCATION 'abfss://gold@datalakestorage000real.dfs.core.windows.net/dim_users/'

# %% [markdown]
# ## dim_districts

# %%
# %sql
CREATE TABLE realstate.gold.dim_districts (
    id BIGINT GENERATED ALWAYS AS IDENTITY,
    district_id INT,
    district_name STRING
)using delta 
LOCATION 'abfss://gold@datalakestorage000real.dfs.core.windows.net/dim_districts/'

# %%
# %sql
select * from realstate.gold.dim_districts limit 2;

# %% [markdown]
# ## dim_citys

# %%
# %sql
CREATE TABLE realstate.gold.dim_cities (
    id BIGINT GENERATED ALWAYS AS IDENTITY,
    city_id INT,
    city_name STRING
)using delta 
LOCATION 'abfss://gold@datalakestorage000real.dfs.core.windows.net/dim_cities/'

# %% [markdown]
# ## dim_categories

# %%
# %sql
CREATE TABLE realstate.gold.dim_categories (
    id BIGINT GENERATED ALWAYS AS IDENTITY,
    property_type STRING,
    transaction_type STRING
)using delta 
LOCATION 'abfss://gold@datalakestorage000real.dfs.core.windows.net/dim_categories/'

# %% [markdown]
# ## dim_property_features

# %%
# %sql
CREATE TABLE realstate.gold.dim_property_features (
    id BIGINT GENERATED ALWAYS AS IDENTITY,
    has_air_condition STRING,
    has_kitchen STRING,
    has_furnished STRING,
    is_daily_rentable STRING,
    rent_period STRING
)using delta 
LOCATION 'abfss://gold@datalakestorage000real.dfs.core.windows.net/dim_property_features/'
-- "has_air_condition","has_kitchen","has_furnished","is_daily_rentable","rent_period"

# %% [markdown]
# ## dim_date

# %%
# %sql
CREATE TABLE IF NOT EXISTS realstate.gold.dim_dates (
        date_key INT,
        date DATE,
        year INT,
        month INT,
        month_name STRING,
        quarter INT,
        day_of_week INT,
        is_weekend INT
    )
    USING delta
    LOCATION 'abfss://gold@datalakestorage000real.dfs.core.windows.net/dim_dates/'

# %% [markdown]
# ## fact_posts

# %%
# %sql
CREATE TABLE realstate.gold.fact_posts (
    row_id INT,
    user_id BIGINT,
    city_id BIGINT,
    district_id BIGINT,
    date_id INT,
    category_id BIGINT,
    property_feature_id BIGINT,
    user_review FLOAT,
    location_lat DECIMAL(10,5),
    location_lng DECIMAL(10,5),
    age INT,
    bathrooms INT,
    bedrooms INT,
    livings INT,
    area DOUBLE,
    price FLOAT
)
USING DELTA
LOCATION 'abfss://gold@datalakestorage000real.dfs.core.windows.net/fact_posts';

# %%
# %sql
select * from realstate.gold.dim_dates limit 10;
-- drop table realstate.gold.dim_dates;

# %%
# %sql
show catalogs

# %%
# %sql 
select * from realstate.silver.posts limit 10

# %%
# %sql
-- drop table realstate.gold.dim_categories;
-- drop table realstate.gold.dim_cities;
-- drop table realstate.gold.dim_districts;
-- drop table realstate.gold.dim_property_features;
-- drop table realstate.gold.dim_users;
-- drop table realstate.gold.fact_posts;

# %%
# %sql
create table realstate.metadata.goldLayer(
    table_name string,
    last_version int
)using delta 
location 'abfss://metadata@datalakestorage000real.dfs.core.windows.net/gold/'

# %%
# %sql
insert into realstate.metadata.goldLayer
values
('users',1),
('district',1),
('city',1),
('category',1),
('property_features',1),
('comments',1)

# %%
# %sql
insert into realstate.metadata.goldLayer
values
('post',1)

# %%
# %sql
update realstate.metadata.goldLayer
set last_version=1
where table_name in ('post')

# %%
# %sql
select * from realstate.metadata.goldLayer

# %%
# %sql 
describe history realstate.silver.posts
